# %%
import pandas as pd 
df = pd.read_csv("WineQT.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# > **Exploring  distributions of numeric columns using histograms**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# set the style for sea born
sns.set(style="whitegrid")

#Create sub plot for each neumeric column
fig, axes= plt.subplots(nrows=3, ncols=4, figsize=(15, 10))

# Flatten the axes array for easire indexing
axes = axes.flatten()

# List of neumeric column
numeric_columns = df.select_dtypes(include=['float64']).columns

# Create histogram for each neumeric columns 
for i, column in enumerate(numeric_columns):
    sns.histplot(df[column], ax=axes[i], kde=True, bins=20, color='blue')
    

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# This code creates histograms for all the numeric columns in a DataFrame (df) that are of type float64. The histograms are displayed in a grid of 3 rows and 4 columns. For each numeric column:
#
# A histogram is generated to show the frequency distribution of values in that column.
# A KDE (Kernel Density Estimate) line is added on top of the histogram to represent the smooth probability distribution of the data.
# Each subplot represents a different numeric column, with each histogram divided into 20 bins.
# If there are more than 12 numeric columns, only the first 12 will be displayed, as the grid can only hold that many subplots.

# %% [markdown]
# # Exploring  relationship between columns using scatter plots

# %% [markdown]
# **scatter plot between fixed acidity and volatile acidity**

# %%
# Scatter plot for fixed acidity vs volatile acidity
plt.figure(figsize=(8, 6))
sns.scatterplot(x='fixed acidity', y='volatile acidity', data=df, color='blue')
plt.title('Scatter Plot of Fixed Acidity vs Volatile Acidity')
plt.xlabel('Fixed Acidity')
plt.ylabel('Volatile Acidity')
plt.show()

# %% [markdown]
# **scatter plot between citric acid and residual sugar**

# %%
# Scatter plot for citric acid vs residual sugar
plt.figure(figsize=(8, 6))
sns.scatterplot(x='citric acid', y='residual sugar', data=df, color='green')
plt.title('Scatter Plot of citric acid and residual sugar')
plt.xlabel('citric acid')
plt.ylabel('residual sugar')
plt.show()

# %% [markdown]
# > **scatter plot between chlorides and free sulpher dioxide**

# %%
# Scatter plot for fixed acidity vs volatile acidity
plt.figure(figsize=(8, 6))
sns.scatterplot(x='chlorides', y='free sulfur dioxide', data=df, color='red')
plt.title('Scatter Plot of chloride and free sulphure dioxide')
plt.xlabel('chlorides')
plt.ylabel('free sulfur dioxide')
plt.show()

# %% [markdown]
# **scatter plot between total sulphure dioxide and density**

# %%
# Scatter plot for fixed acidity vs volatile acidity
plt.figure(figsize=(8, 6))
sns.scatterplot(x='total sulfur dioxide', y='density', data=df, color='purple')
plt.title('Scatter Plot of total surface dioxide and  density ')
plt.xlabel('total sulfur dioxide ')
plt.ylabel('density')
plt.show()

# %% [markdown]
# **scatter plot between pH and sulphate**

# %%
# Scatter plot for fixed acidity vs volatile acidity
plt.figure(figsize=(8, 6))
sns.scatterplot(x='pH', y='sulphates', data=df, color='orange')
plt.title('Scatter Plot of pH and sulphate')
plt.xlabel('pH ')
plt.ylabel('sulphates')
plt.show()

# %% [markdown]
# # Short note

# %% [markdown]
# The data set,consisting of various wine-related features,reveals insights through mean,sum,rangeand count with the help of  Numerica columns scatter plot has been done on data set deeper exploration analysis provides valuable insights into the datasets characteristics and sets the stage for future investigation.

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
print(df.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %% [markdown]
# # Four Interesting question about the dataset

# %% [markdown]
# **1)What is the distribution of 'fixed acidity' in the dataset?**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram for 'fixed acidity' distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['fixed acidity'], bins=20, kde=True, color='blue', edgecolor='black')
plt.title('Distribution of Fixed Acidity')
plt.xlabel('Fixed Acidity')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **2)Is there a correlation between 'density' and 'pH'?**

# %%
# Scatter plot for 'density' vs 'pH'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='density', y='pH', data=df, color='red')
plt.title('Relationship between Density and pH')
plt.xlabel('Density')
plt.ylabel('pH')
plt.show()

# %% [markdown]
# **3)What is the most common range of 'total sulfur dioxide' in the dataset?**

# %%
# Boxplot for 'total sulfur dioxide'
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['total sulfur dioxide'])
plt.title('Distribution of Total Sulfur Dioxide')
plt.xlabel('Total Sulfur Dioxide')
plt.show()

# %% [markdown]
# **4)How do 'volatile acidity' and 'citric acid' vary together?**

# %%
# scatter plot for volatile acid and citric acid 
plt.figure(figsize=(10, 6))
sns.scatterplot(x='volatile acidity', y='citric acid', data=df, color='green')
plt.title('Relationship between volatile acidity and citric acid')
plt.xlabel('volatile acidity')
plt.ylabel('citric acid')
plt.show()

# %% [markdown]
# # Created new columns total_acidity and sulfur_ratio

# %%
df['total_acidity'] = df['fixed acidity'] + df['volatile acidity']
df['sulfur_ratio'] = df['free sulfur dioxide'] / df['total sulfur dioxide']
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id  total_acidity  sulfur_ratio
# ...

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
#Create sub plot for each neumeric column
fig, axes= plt.subplots(nrows=5, ncols=3, figsize=(18,14))

# Flatten the axes array for easire indexing
axes = axes.flatten()

# List of neumeric column
numeric_columns = df.select_dtypes(include=['float64']).columns

# Create histogram for each neumeric columns 
for i, column in enumerate(numeric_columns):
    sns.boxplot(x='quality', y=column, ax=axes[i], data=df)
    

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Summary

# %% [markdown]
# The data set consists of diverse numeric fetures related to wine properties.     The distribution of these features varies ,with some having a relatively wide range of values.Relationship between certain columns explored ,providing insights into potential correlations.
# Aditional columns were created to enchance the dataset for futher analysis.
# merging operations were demonstrated ,emphasizing the importance of selecting appropriate common columns.
# This summery captures the key findings and opertaions performed during the exploratorary analysis ,providing a foundation for more in depth investigations  or modeling tasks.
